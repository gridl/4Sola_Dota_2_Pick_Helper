# %%
import pandas as pd

# %%
heroes_data = pd.read_csv('hand_made_file.csv', index_col=0)
heroes_data.head(20)
# Out:
#                   pick_1k  win_1k  pick_2k  win_2k  pick_3k  win_3k  pick_4k  \
# Hero
# Pudge               33.99   51.94    35.27   51.55    34.73   51.33    31.93
# Sniper              28.17   51.66    19.68   51.99    14.11   51.60    10.28
# Drow Ranger         27.34   52.92    24.71   56.32    23.10   57.95    22.01
# Lion                27.11   47.50    26.57   47.50    26.32   47.88    25.32
# Phantom Assassin    24.07   48.65    19.38   47.22    16.33   46.89    13.48
# Juggernaut          20.59   50.60    22.44   51.36    22.94   51.77    23.58
# Windranger          20.21   52.41    18.55   53.04    18.58   52.91    19.46
# Legion Commander    17.11   50.97    13.01   49.66    10.52   48.95     8.81
# Crystal Maiden      16.00   56.94    15.31   55.53    14.00   54.50    12.67
# Monkey King         15.74   49.78    15.66   50.58    17.18   50.78    20.13
# Wraith King         15.45   57.53    13.78   56.61    12.73   55.08    12.88
# ...

# %%
heroes_data.pick_1k[0]
# Out:
# numpy.float64
